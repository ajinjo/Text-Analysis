# %%
import pandas as pd
import numpy as np
import os

# %%
import os
path='C:/'
file_list=os.listdir
file_list_py=[file for file in file_]

# %%
entry = pd.read_csv('C:/data/entry/2020/2020-05-05_entry.csv')
entry
# Out:
#       등번호   이름  투타유형        생년월일           체격   구분 team
# 0    70.0  이동욱  우투우타  1974-07-17  179cm, 81kg   감독   NC
# 1    27.0  이호준  우투우타  1976-02-08  187cm, 95kg   코치   NC
# 2    74.0  한규식  우투우타  1976-09-14  176cm, 78kg   코치   NC
# 3    75.0  진종길  우투좌타  1981-09-23  178cm, 80kg   코치   NC
# 4    77.0  용덕한  우투우타  1981-04-09  176cm, 82kg   코치   NC
# ..    ...  ...   ...         ...          ...  ...  ...
# 362   NaN  장진혁  우투좌타  1993-09-30  184cm, 83kg  외야수   한화
# 363   NaN   호잉  우투좌타  1989-05-18  190cm, 92kg  외야수   한화
# 364  10.0  장운호  우투우타  1994-02-20  183cm, 85kg  외야수   한화
# 365  19.0  이용규  좌투좌타  1985-08-26  175cm, 70kg  외야수   한화
# 366  33.0  정진호  우투좌타  1988-10-02  185cm, 78kg  외야수   한화
#
# [367 rows x 7 columns]

# %%
entry['선발유무']=0

# %%
entry
# Out:
#       등번호   이름  투타유형        생년월일           체격   구분 team  선발유무
# 0    70.0  이동욱  우투우타  1974-07-17  179cm, 81kg   감독   NC     0
# 1    27.0  이호준  우투우타  1976-02-08  187cm, 95kg   코치   NC     0
# 2    74.0  한규식  우투우타  1976-09-14  176cm, 78kg   코치   NC     0
# 3    75.0  진종길  우투좌타  1981-09-23  178cm, 80kg   코치   NC     0
# 4    77.0  용덕한  우투우타  1981-04-09  176cm, 82kg   코치   NC     0
# ..    ...  ...   ...         ...          ...  ...  ...   ...
# 362   NaN  장진혁  우투좌타  1993-09-30  184cm, 83kg  외야수   한화     0
# 363   NaN   호잉  우투좌타  1989-05-18  190cm, 92kg  외야수   한화     0
# 364  10.0  장운호  우투우타  1994-02-20  183cm, 85kg  외야수   한화     0
# 365  19.0  이용규  좌투좌타  1985-08-26  175cm, 70kg  외야수   한화     0
# 366  33.0  정진호  우투좌타  1988-10-02  185cm, 78kg  외야수   한화     0
#
# [367 rows x 8 columns]

# %%
#라인업 확인
lineup = pd.read_csv('C:/data/game/2020-05-05/라이온즈파크_14/lineup_record.csv')
lineup
# Out:
#      타순               이름   포지션    투타 team
# 0   1.0   박민우_1993-02-06   2루수  우투좌타   NC
# 1   2.0   알테어_1991-01-14   중견수  우투우타   NC
# 2   3.0   나성범_1989-10-03  지명타자  좌투좌타   NC
# 3   4.0   양의지_1987-06-05    포수  우투우타   NC
# 4   5.0   박석민_1985-06-22   3루수  우투우타   NC
# 5   6.0   모창민_1985-05-08   1루수  우투우타   NC
# 6   7.0   노진혁_1989-07-15   유격수  우투좌타   NC
# 7   8.0   김성욱_1993-05-01   우익수  우투우타   NC
# 8   9.0   이명기_1987-12-26   좌익수  좌투좌타   NC
# 9   NaN  루친스키_1988-12-30    투수  우투우타   NC
# 10  1.0   김헌곤_1988-11-09   우익수  우투우타   삼성
# 11  2.0   구자욱_1993-02-12   좌익수  우투좌타   삼성
# 12  3.0  살라디노_1989-07-20   유격수  우투우타   삼성
# 13  4.0   이원석_1986-10-21   3루수  우투우타   삼성
# 14  5.0   김상수_1990-03-23   2루수  우투우타   삼성
# 15  6.0   김동엽_1990-07-24  지명타자  우투우타   삼성
# 16  7.0   강민호_1985-08-18    포수  우투우타   삼성
# 17  8.0   박해민_1990-02-24   중견수  우투좌타   삼성
# 18  9.0   이성규_1993-08-03   1루수  우투우타   삼성
# 19  NaN   백정현_1987-07-13    투수  좌투좌타   삼성

# %%
df = lineup['이름']
df
# Out:
# 0      박민우_1993-02-06
# 1      알테어_1991-01-14
# 2      나성범_1989-10-03
# 3      양의지_1987-06-05
# 4      박석민_1985-06-22
# 5      모창민_1985-05-08
# 6      노진혁_1989-07-15
# 7      김성욱_1993-05-01
# 8      이명기_1987-12-26
# 9     루친스키_1988-12-30
# 10     김헌곤_1988-11-09
# 11     구자욱_1993-02-12
# 12    살라디노_1989-07-20
# 13     이원석_1986-10-21
# 14     김상수_1990-03-23
# 15     김동엽_1990-07-24
# 16     강민호_1985-08-18
# 17     박해민_1990-02-24
# 18     이성규_1993-08-03
# 19     백정현_1987-07-13
# Name: 이름, dtype: object

# %%
lineup['생년월일']=0

# %%
lineup=lineup
lineup
# Out:
#      타순               이름   포지션    투타 team  생년월일
# 0   1.0   박민우_1993-02-06   2루수  우투좌타   NC     0
# 1   2.0   알테어_1991-01-14   중견수  우투우타   NC     0
# 2   3.0   나성범_1989-10-03  지명타자  좌투좌타   NC     0
# 3   4.0   양의지_1987-06-05    포수  우투우타   NC     0
# 4   5.0   박석민_1985-06-22   3루수  우투우타   NC     0
# 5   6.0   모창민_1985-05-08   1루수  우투우타   NC     0
# 6   7.0   노진혁_1989-07-15   유격수  우투좌타   NC     0
# 7   8.0   김성욱_1993-05-01   우익수  우투우타   NC     0
# 8   9.0   이명기_1987-12-26   좌익수  좌투좌타   NC     0
# 9   NaN  루친스키_1988-12-30    투수  우투우타   NC     0
# 10  1.0   김헌곤_1988-11-09   우익수  우투우타   삼성     0
# 11  2.0   구자욱_1993-02-12   좌익수  우투좌타   삼성     0
# 12  3.0  살라디노_1989-07-20   유격수  우투우타   삼성     0
# 13  4.0   이원석_1986-10-21   3루수  우투우타   삼성     0
# 14  5.0   김상수_1990-03-23   2루수  우투우타   삼성     0
# 15  6.0   김동엽_1990-07-24  지명타자  우투우타   삼성     0
# 16  7.0   강민호_1985-08-18    포수  우투우타   삼성     0
# 17  8.0   박해민_1990-02-24   중견수  우투좌타   삼성     0
# 18  9.0   이성규_1993-08-03   1루수  우투우타   삼성     0
# ...

# %%
lineup['이름_0']=0

# %%
for i in range(df.shape[0]):
    lineup.loc[i, '생년월일'] = str(lineup.loc[i, '이름']).split('_')[1]
    lineup.loc[i, '이름_0'] = str(lineup.loc[i, '이름']).split('_')[0]

# %%
lineup
# Out:
#      타순               이름   포지션    투타 team        생년월일  이름_0
# 0   1.0   박민우_1993-02-06   2루수  우투좌타   NC  1993-02-06   박민우
# 1   2.0   알테어_1991-01-14   중견수  우투우타   NC  1991-01-14   알테어
# 2   3.0   나성범_1989-10-03  지명타자  좌투좌타   NC  1989-10-03   나성범
# 3   4.0   양의지_1987-06-05    포수  우투우타   NC  1987-06-05   양의지
# 4   5.0   박석민_1985-06-22   3루수  우투우타   NC  1985-06-22   박석민
# 5   6.0   모창민_1985-05-08   1루수  우투우타   NC  1985-05-08   모창민
# 6   7.0   노진혁_1989-07-15   유격수  우투좌타   NC  1989-07-15   노진혁
# 7   8.0   김성욱_1993-05-01   우익수  우투우타   NC  1993-05-01   김성욱
# 8   9.0   이명기_1987-12-26   좌익수  좌투좌타   NC  1987-12-26   이명기
# 9   NaN  루친스키_1988-12-30    투수  우투우타   NC  1988-12-30  루친스키
# 10  1.0   김헌곤_1988-11-09   우익수  우투우타   삼성  1988-11-09   김헌곤
# 11  2.0   구자욱_1993-02-12   좌익수  우투좌타   삼성  1993-02-12   구자욱
# 12  3.0  살라디노_1989-07-20   유격수  우투우타   삼성  1989-07-20  살라디노
# 13  4.0   이원석_1986-10-21   3루수  우투우타   삼성  1986-10-21   이원석
# 14  5.0   김상수_1990-03-23   2루수  우투우타   삼성  1990-03-23   김상수
# ...

# %%
lineup[lineup['포지션']=='투수']
# Out:
#     타순               이름 포지션    투타 team        생년월일  이름_0
# 9  NaN  루친스키_1988-12-30  투수  우투우타   NC  1988-12-30  루친스키
# 19 NaN   백정현_1987-07-13  투수  좌투좌타   삼성  1987-07-13   백정현

# %%
lineup2=lineup[lineup['포지션']=='투수']['생년월일']
lineup2
# Out:
# 9     1988-12-30
# 19    1987-07-13
# Name: 생년월일, dtype: object

# %%
lineup[lineup['포지션']=='투수']['생년월일'].values
# Out:
# array(['1988-12-30', '1987-07-13'], dtype=object)

# %%
lineup3.values
# Out:
# array(['루친스키', '백정현'], dtype=object)

# %%
entry['생년월일'].values
# Out:
# array(['1974-07-17', '1976-02-08', '1976-09-14', '1981-09-23',
#        '1981-04-09', '1975-01-02', '1972-06-26', '1977-12-03',
#        '1980-06-18', '1990-01-03', '1991-10-02', '1990-02-12',
#        '1990-04-16', '1988-12-30', '1985-08-25', '1987-07-31',
#        '1997-02-17', '1995-02-24', '1990-07-10', '1987-06-05',
#        '1989-12-30', '1993-02-06', '1997-12-29', '1989-02-05',
#        '1985-05-08', '1985-06-22', '1995-10-07', '1989-05-20',
#        '1989-07-15', '2000-06-24', '1991-01-20', '1991-01-14',
#        '1993-05-01', '1987-12-26', '1990-12-30', '1989-10-03',
#        '1993-10-19', '1967-09-12', '1972-07-05', '1975-05-24',
#        '1975-05-25', '1976-12-23', '1973-01-03', '1974-04-20',
#        '1967-12-07', '1984-02-08', '1995-01-13', '1993-12-15',
#        '1994-07-01', '1995-07-11', '1989-06-18', '1992-12-04',
#        '1983-10-11', '1997-11-01', '1994-12-21', '1998-03-10',
#        '1994-02-27', '1990-01-09', '1989-05-16', '1982-12-24',
# ...

# %%
df.loc[df['math']>=90]

# %%
entry.loc[entry['생년월일'].values = lineup[lineup['포지션']=='투수']['생년월일'].values ]
# Out:
#   File "<ipython-input-126-d7be337b5b25>", line 1
#     entry.loc[entry['생년월일'].values = lineup[lineup['포지션']=='투수']['생년월일'].values ]
#                                    ^
# SyntaxError: invalid syntax

# %%
entry['이름'].values
# Out:
# array(['이동욱', '이호준', '한규식', '진종길', '용덕한', '손민한', '강인권', '채종범', '이종욱',
#        '라이트', '김건태', '박진우', '임정호', '루친스키', '임창민', '원종현', '구창모', '배재환',
#        '강윤구', '양의지', '김태군', '박민우', '김찬형', '이상호', '모창민', '박석민', '김태진',
#        '이원재', '노진혁', '최정원', '김준완', '알테어', '김성욱', '이명기', '권희동', '나성범',
#        '강진성', '김태형', '김원형', '이도형', '조인성', '조성환', '김민재', '강동우', '강석천',
#        '고영민', '함덕주', '이동원', '플렉센', '채지선', '윤명준', '알칸타라', '이현승', '이영하',
#        '최원준', '박치국', '이형범', '박세혁', '이흥련', '정상호', '류지혁', '페르난데스', '허경민',
#        '이유찬', '오재원', '오재일', '김재호', '최주환', '국해성', '안권수', '정수빈', '김재환',
#        '박건우', '김인태', '이강철', '김태균', '김강', '박기혁', '박철영', '박정환', '최만호',
#        '박승민', '조중근', '이대은', '배제성', '이상화', '김민수', '하준호', '전유수', '쿠에바스',
#        '주권', '데스파이네', '손동현', '김재윤', '허도환', '장성우', '강현우', '심우준', '박경수',
#        '강민국', '황재균', '김병희', '박승욱', '오태곤', '송민섭', '조용호', '로하스', '배정대',
#        '강백호', '김민혁', '유한준', '류중일', '류지현', '이병규', '임훈', '최일언', '김재걸',
# ...

# %%
lineup['이름_0'].values
# Out:
# array(['박민우', '알테어', '나성범', '양의지', '박석민', '모창민', '노진혁', '김성욱', '이명기',
#        '루친스키', '김헌곤', '구자욱', '살라디노', '이원석', '김상수', '김동엽', '강민호', '박해민',
#        '이성규', '백정현'], dtype=object)

# %%
entry.loc[entry['생년월일'].values = lineup[lineup['포지션']=='투수']['생년월일'].values ]

# %%
condition = (entry['생년월일'].values ==  lineup[lineup['포지션']=='투수']['생년월일'].values) & (entry['이름'].values ==  lineup[lineup['포지션']=='투수']['이름_0'].values) # 조건식 작성

df[condition]
# Out:
# <ipython-input-132-4cfa4e87aed2>:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   condition = (entry['생년월일'].values ==  lineup[lineup['포지션']=='투수']['생년월일'].values) & (entry['이름'].values ==  lineup[lineup['포지션']=='투수']['이름_0'].values) # 조건식 작성
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-4cfa4e87aed2> in <module>
#       1 condition = (entry['생년월일'].values ==  lineup[lineup['포지션']=='투수']['생년월일'].values) & (entry['이름'].values ==  lineup[lineup['포지션']=='투수']['이름_0'].values) # 조건식 작성
#       2
# ----> 3 df[condition]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ...

# %%
iris["new_columns"] = np.where( iris["sepal_length"].values > 5 , "Large","Small" )
iris.head()

# %%
entry
# Out:
#       등번호   이름  투타유형        생년월일           체격   구분 team  선발유무
# 0    70.0  이동욱  우투우타  1974-07-17  179cm, 81kg   감독   NC     0
# 1    27.0  이호준  우투우타  1976-02-08  187cm, 95kg   코치   NC     0
# 2    74.0  한규식  우투우타  1976-09-14  176cm, 78kg   코치   NC     0
# 3    75.0  진종길  우투좌타  1981-09-23  178cm, 80kg   코치   NC     0
# 4    77.0  용덕한  우투우타  1981-04-09  176cm, 82kg   코치   NC     0
# ..    ...  ...   ...         ...          ...  ...  ...   ...
# 362   NaN  장진혁  우투좌타  1993-09-30  184cm, 83kg  외야수   한화     0
# 363   NaN   호잉  우투좌타  1989-05-18  190cm, 92kg  외야수   한화     0
# 364  10.0  장운호  우투우타  1994-02-20  183cm, 85kg  외야수   한화     0
# 365  19.0  이용규  좌투좌타  1985-08-26  175cm, 70kg  외야수   한화     0
# 366  33.0  정진호  우투좌타  1988-10-02  185cm, 78kg  외야수   한화     0
#
# [367 rows x 8 columns]

# %%
lineup
# Out:
#      타순               이름   포지션    투타 team        생년월일  이름_0
# 0   1.0   박민우_1993-02-06   2루수  우투좌타   NC  1993-02-06   박민우
# 1   2.0   알테어_1991-01-14   중견수  우투우타   NC  1991-01-14   알테어
# 2   3.0   나성범_1989-10-03  지명타자  좌투좌타   NC  1989-10-03   나성범
# 3   4.0   양의지_1987-06-05    포수  우투우타   NC  1987-06-05   양의지
# 4   5.0   박석민_1985-06-22   3루수  우투우타   NC  1985-06-22   박석민
# 5   6.0   모창민_1985-05-08   1루수  우투우타   NC  1985-05-08   모창민
# 6   7.0   노진혁_1989-07-15   유격수  우투좌타   NC  1989-07-15   노진혁
# 7   8.0   김성욱_1993-05-01   우익수  우투우타   NC  1993-05-01   김성욱
# 8   9.0   이명기_1987-12-26   좌익수  좌투좌타   NC  1987-12-26   이명기
# 9   NaN  루친스키_1988-12-30    투수  우투우타   NC  1988-12-30  루친스키
# 10  1.0   김헌곤_1988-11-09   우익수  우투우타   삼성  1988-11-09   김헌곤
# 11  2.0   구자욱_1993-02-12   좌익수  우투좌타   삼성  1993-02-12   구자욱
# 12  3.0  살라디노_1989-07-20   유격수  우투우타   삼성  1989-07-20  살라디노
# 13  4.0   이원석_1986-10-21   3루수  우투우타   삼성  1986-10-21   이원석
# 14  5.0   김상수_1990-03-23   2루수  우투우타   삼성  1990-03-23   김상수
# ...

# %%
entry[lineup['이름_0'].values = entry['이름'].values]
# Out:
#   File "<ipython-input-145-5049ad39007f>", line 1
#     entry[lineup['이름_0'].values = entry['이름'].values]
#                                 ^
# SyntaxError: invalid syntax

# %%
lineup['이름_0'].values
# Out:
# array(['박민우', '알테어', '나성범', '양의지', '박석민', '모창민', '노진혁', '김성욱', '이명기',
#        '루친스키', '김헌곤', '구자욱', '살라디노', '이원석', '김상수', '김동엽', '강민호', '박해민',
#        '이성규', '백정현'], dtype=object)

# %%
entry['이름'].values
# Out:
# array(['이동욱', '이호준', '한규식', '진종길', '용덕한', '손민한', '강인권', '채종범', '이종욱',
#        '라이트', '김건태', '박진우', '임정호', '루친스키', '임창민', '원종현', '구창모', '배재환',
#        '강윤구', '양의지', '김태군', '박민우', '김찬형', '이상호', '모창민', '박석민', '김태진',
#        '이원재', '노진혁', '최정원', '김준완', '알테어', '김성욱', '이명기', '권희동', '나성범',
#        '강진성', '김태형', '김원형', '이도형', '조인성', '조성환', '김민재', '강동우', '강석천',
#        '고영민', '함덕주', '이동원', '플렉센', '채지선', '윤명준', '알칸타라', '이현승', '이영하',
#        '최원준', '박치국', '이형범', '박세혁', '이흥련', '정상호', '류지혁', '페르난데스', '허경민',
#        '이유찬', '오재원', '오재일', '김재호', '최주환', '국해성', '안권수', '정수빈', '김재환',
#        '박건우', '김인태', '이강철', '김태균', '김강', '박기혁', '박철영', '박정환', '최만호',
#        '박승민', '조중근', '이대은', '배제성', '이상화', '김민수', '하준호', '전유수', '쿠에바스',
#        '주권', '데스파이네', '손동현', '김재윤', '허도환', '장성우', '강현우', '심우준', '박경수',
#        '강민국', '황재균', '김병희', '박승욱', '오태곤', '송민섭', '조용호', '로하스', '배정대',
#        '강백호', '김민혁', '유한준', '류중일', '류지현', '이병규', '임훈', '최일언', '김재걸',
# ...

# %%
entry
# Out:
#       등번호   이름  투타유형        생년월일           체격   구분 team  선발유무
# 0    70.0  이동욱  우투우타  1974-07-17  179cm, 81kg   감독   NC     0
# 1    27.0  이호준  우투우타  1976-02-08  187cm, 95kg   코치   NC     0
# 2    74.0  한규식  우투우타  1976-09-14  176cm, 78kg   코치   NC     0
# 3    75.0  진종길  우투좌타  1981-09-23  178cm, 80kg   코치   NC     0
# 4    77.0  용덕한  우투우타  1981-04-09  176cm, 82kg   코치   NC     0
# ..    ...  ...   ...         ...          ...  ...  ...   ...
# 362   NaN  장진혁  우투좌타  1993-09-30  184cm, 83kg  외야수   한화     0
# 363   NaN   호잉  우투좌타  1989-05-18  190cm, 92kg  외야수   한화     0
# 364  10.0  장운호  우투우타  1994-02-20  183cm, 85kg  외야수   한화     0
# 365  19.0  이용규  좌투좌타  1985-08-26  175cm, 70kg  외야수   한화     0
# 366  33.0  정진호  우투좌타  1988-10-02  185cm, 78kg  외야수   한화     0
#
# [367 rows x 8 columns]

# %%
lineup
# Out:
#      타순               이름   포지션    투타 team        생년월일  이름_0
# 0   1.0   박민우_1993-02-06   2루수  우투좌타   NC  1993-02-06   박민우
# 1   2.0   알테어_1991-01-14   중견수  우투우타   NC  1991-01-14   알테어
# 2   3.0   나성범_1989-10-03  지명타자  좌투좌타   NC  1989-10-03   나성범
# 3   4.0   양의지_1987-06-05    포수  우투우타   NC  1987-06-05   양의지
# 4   5.0   박석민_1985-06-22   3루수  우투우타   NC  1985-06-22   박석민
# 5   6.0   모창민_1985-05-08   1루수  우투우타   NC  1985-05-08   모창민
# 6   7.0   노진혁_1989-07-15   유격수  우투좌타   NC  1989-07-15   노진혁
# 7   8.0   김성욱_1993-05-01   우익수  우투우타   NC  1993-05-01   김성욱
# 8   9.0   이명기_1987-12-26   좌익수  좌투좌타   NC  1987-12-26   이명기
# 9   NaN  루친스키_1988-12-30    투수  우투우타   NC  1988-12-30  루친스키
# 10  1.0   김헌곤_1988-11-09   우익수  우투우타   삼성  1988-11-09   김헌곤
# 11  2.0   구자욱_1993-02-12   좌익수  우투좌타   삼성  1993-02-12   구자욱
# 12  3.0  살라디노_1989-07-20   유격수  우투우타   삼성  1989-07-20  살라디노
# 13  4.0   이원석_1986-10-21   3루수  우투우타   삼성  1986-10-21   이원석
# 14  5.0   김상수_1990-03-23   2루수  우투우타   삼성  1990-03-23   김상수
# ...

# %%
lineup['이름']=lineup['이름_0']

# %%
lineup
# Out:
#      타순    이름   포지션    투타 team        생년월일  이름_0  선발유무
# 0   1.0   박민우   2루수  우투좌타   NC  1993-02-06   박민우     0
# 1   2.0   알테어   중견수  우투우타   NC  1991-01-14   알테어     0
# 2   3.0   나성범  지명타자  좌투좌타   NC  1989-10-03   나성범     0
# 3   4.0   양의지    포수  우투우타   NC  1987-06-05   양의지     0
# 4   5.0   박석민   3루수  우투우타   NC  1985-06-22   박석민     0
# 5   6.0   모창민   1루수  우투우타   NC  1985-05-08   모창민     0
# 6   7.0   노진혁   유격수  우투좌타   NC  1989-07-15   노진혁     0
# 7   8.0   김성욱   우익수  우투우타   NC  1993-05-01   김성욱     0
# 8   9.0   이명기   좌익수  좌투좌타   NC  1987-12-26   이명기     0
# 9   NaN  루친스키    투수  우투우타   NC  1988-12-30  루친스키     1
# 10  1.0   김헌곤   우익수  우투우타   삼성  1988-11-09   김헌곤     0
# 11  2.0   구자욱   좌익수  우투좌타   삼성  1993-02-12   구자욱     0
# 12  3.0  살라디노   유격수  우투우타   삼성  1989-07-20  살라디노     0
# 13  4.0   이원석   3루수  우투우타   삼성  1986-10-21   이원석     0
# 14  5.0   김상수   2루수  우투우타   삼성  1990-03-23   김상수     0
# 15  6.0   김동엽  지명타자  우투우타   삼성  1990-07-24   김동엽     0
# ...

# %%
lineup['선발유무'] = np.where(lineup['포지션'] == '투수',1,0)

# %%
lineup
# Out:
#      타순    이름   포지션    투타 team        생년월일  이름_0  선발유무
# 0   1.0   박민우   2루수  우투좌타   NC  1993-02-06   박민우     0
# 1   2.0   알테어   중견수  우투우타   NC  1991-01-14   알테어     0
# 2   3.0   나성범  지명타자  좌투좌타   NC  1989-10-03   나성범     0
# 3   4.0   양의지    포수  우투우타   NC  1987-06-05   양의지     0
# 4   5.0   박석민   3루수  우투우타   NC  1985-06-22   박석민     0
# 5   6.0   모창민   1루수  우투우타   NC  1985-05-08   모창민     0
# 6   7.0   노진혁   유격수  우투좌타   NC  1989-07-15   노진혁     0
# 7   8.0   김성욱   우익수  우투우타   NC  1993-05-01   김성욱     0
# 8   9.0   이명기   좌익수  좌투좌타   NC  1987-12-26   이명기     0
# 9   NaN  루친스키    투수  우투우타   NC  1988-12-30  루친스키     1
# 10  1.0   김헌곤   우익수  우투우타   삼성  1988-11-09   김헌곤     0
# 11  2.0   구자욱   좌익수  우투좌타   삼성  1993-02-12   구자욱     0
# 12  3.0  살라디노   유격수  우투우타   삼성  1989-07-20  살라디노     0
# 13  4.0   이원석   3루수  우투우타   삼성  1986-10-21   이원석     0
# 14  5.0   김상수   2루수  우투우타   삼성  1990-03-23   김상수     0
# 15  6.0   김동엽  지명타자  우투우타   삼성  1990-07-24   김동엽     0
# ...

# %%
pd.merge(entry, lineup, on = '이름')
# Out:
#      등번호    이름  투타유형      생년월일_x            체격   구분 team_x  선발유무_x   타순   포지션  \
# 0   40.0  루친스키  우투우타  1988-12-30   188cm, 91kg   투수     NC       0  NaN    투수
# 1   25.0   양의지  우투우타  1987-06-05   179cm, 85kg   포수     NC       0  4.0    포수
# 2    2.0   박민우  우투좌타  1993-02-06   185cm, 80kg  내야수     NC       0  1.0   2루수
# 3   16.0   모창민  우투우타  1985-05-08   188cm, 89kg  내야수     NC       0  6.0   1루수
# 4   18.0   박석민  우투우타  1985-06-22   178cm, 88kg  내야수     NC       0  5.0   3루수
# 5   52.0   노진혁  우투좌타  1989-07-15   184cm, 80kg  내야수     NC       0  7.0   유격수
# 6   23.0   알테어  우투우타  1991-01-14   196cm, 97kg  외야수     NC       0  2.0   중견수
# 7   31.0   김성욱  우투우타  1993-05-01   181cm, 83kg  외야수     NC       0  8.0   우익수
# 8   33.0   이명기  좌투좌타  1987-12-26   183cm, 87kg  외야수     NC       0  9.0   좌익수
# 9   47.0   나성범  좌투좌타  1989-10-03  183cm, 100kg  외야수     NC       0  3.0  지명타자
# 10  24.0   김상수  우투우타  1988-01-02   180cm, 88kg   투수     키움       0  5.0   2루수
# ...

# %%
pd.merge(entry, lineup, on = '이름', how = 'left')
# Out:
#       등번호   이름  투타유형      생년월일_x           체격   구분 team_x  선발유무_x  타순  포지션  \
# 0    70.0  이동욱  우투우타  1974-07-17  179cm, 81kg   감독     NC       0 NaN  NaN
# 1    27.0  이호준  우투우타  1976-02-08  187cm, 95kg   코치     NC       0 NaN  NaN
# 2    74.0  한규식  우투우타  1976-09-14  176cm, 78kg   코치     NC       0 NaN  NaN
# 3    75.0  진종길  우투좌타  1981-09-23  178cm, 80kg   코치     NC       0 NaN  NaN
# 4    77.0  용덕한  우투우타  1981-04-09  176cm, 82kg   코치     NC       0 NaN  NaN
# ..    ...  ...   ...         ...          ...  ...    ...     ...  ..  ...
# 362   NaN  장진혁  우투좌타  1993-09-30  184cm, 83kg  외야수     한화       0 NaN  NaN
# 363   NaN   호잉  우투좌타  1989-05-18  190cm, 92kg  외야수     한화       0 NaN  NaN
# 364  10.0  장운호  우투우타  1994-02-20  183cm, 85kg  외야수     한화       0 NaN  NaN
# 365  19.0  이용규  좌투좌타  1985-08-26  175cm, 70kg  외야수     한화       0 NaN  NaN
# 366  33.0  정진호  우투좌타  1988-10-02  185cm, 78kg  외야수     한화       0 NaN  NaN
#
#       투타 team_y 생년월일_y 이름_0  선발유무_y
# ...

# %%
entry
# Out:
#       등번호   이름  투타유형        생년월일           체격   구분 team  선발유무
# 0    70.0  이동욱  우투우타  1974-07-17  179cm, 81kg   감독   NC     0
# 1    27.0  이호준  우투우타  1976-02-08  187cm, 95kg   코치   NC     0
# 2    74.0  한규식  우투우타  1976-09-14  176cm, 78kg   코치   NC     0
# 3    75.0  진종길  우투좌타  1981-09-23  178cm, 80kg   코치   NC     0
# 4    77.0  용덕한  우투우타  1981-04-09  176cm, 82kg   코치   NC     0
# ..    ...  ...   ...         ...          ...  ...  ...   ...
# 362   NaN  장진혁  우투좌타  1993-09-30  184cm, 83kg  외야수   한화     0
# 363   NaN   호잉  우투좌타  1989-05-18  190cm, 92kg  외야수   한화     0
# 364  10.0  장운호  우투우타  1994-02-20  183cm, 85kg  외야수   한화     0
# 365  19.0  이용규  좌투좌타  1985-08-26  175cm, 70kg  외야수   한화     0
# 366  33.0  정진호  우투좌타  1988-10-02  185cm, 78kg  외야수   한화     0
#
# [367 rows x 8 columns]

# %%
pd.merge(entry, lineup, on = '이름', how = 'left')
# Out:
#       등번호   이름  투타유형      생년월일_x           체격   구분 team_x  선발유무_x  타순  포지션  \
# 0    70.0  이동욱  우투우타  1974-07-17  179cm, 81kg   감독     NC       0 NaN  NaN
# 1    27.0  이호준  우투우타  1976-02-08  187cm, 95kg   코치     NC       0 NaN  NaN
# 2    74.0  한규식  우투우타  1976-09-14  176cm, 78kg   코치     NC       0 NaN  NaN
# 3    75.0  진종길  우투좌타  1981-09-23  178cm, 80kg   코치     NC       0 NaN  NaN
# 4    77.0  용덕한  우투우타  1981-04-09  176cm, 82kg   코치     NC       0 NaN  NaN
# ..    ...  ...   ...         ...          ...  ...    ...     ...  ..  ...
# 362   NaN  장진혁  우투좌타  1993-09-30  184cm, 83kg  외야수     한화       0 NaN  NaN
# 363   NaN   호잉  우투좌타  1989-05-18  190cm, 92kg  외야수     한화       0 NaN  NaN
# 364  10.0  장운호  우투우타  1994-02-20  183cm, 85kg  외야수     한화       0 NaN  NaN
# 365  19.0  이용규  좌투좌타  1985-08-26  175cm, 70kg  외야수     한화       0 NaN  NaN
# 366  33.0  정진호  우투좌타  1988-10-02  185cm, 78kg  외야수     한화       0 NaN  NaN
#
#       투타 team_y 생년월일_y 이름_0  선발유무_y
# ...

# %%
pd.merge(entry, lineup, on = '이름', how = 'left')[pd.merge(entry, lineup, on = '이름', how = 'left')['선발유무_y']==1]
# Out:
#       등번호    이름  투타유형      생년월일_x           체격  구분 team_x  선발유무_x  타순 포지션  \
# 13   40.0  루친스키  우투우타  1988-12-30  188cm, 91kg  투수     NC       0 NaN  투수
# 271  29.0   백정현  좌투좌타  1987-07-13  184cm, 80kg  투수     삼성       0 NaN  투수
#
#        투타 team_y      생년월일_y  이름_0  선발유무_y
# 13   우투우타     NC  1988-12-30  루친스키     1.0
# 271  좌투좌타     삼성  1987-07-13   백정현     1.0

# %%
pd.merge(entry, lineup, on = '이름', how = 'left')[pd.merge(entry, lineup, on = '이름', how = 'left')['선발유무_y']==1]['선발유무_y']
# Out:
# 13     1.0
# 271    1.0
# Name: 선발유무_y, dtype: float64

# %%
pd.merge(left, right, on = 'col', how = 'left')

# %%
entry['선발유무'] = np.where(entry['생년월일'].values == lineup[lineup['포지션']=='투수']['생년월일'],1,0)
# Out:
# <ipython-input-134-7d391906583f>:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   entry['선발유무'] = np.where(entry['생년월일'].values == lineup[lineup['포지션']=='투수']['생년월일'],1,0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-7d391906583f> in <module>
# ----> 1 entry['선발유무'] = np.where(entry['생년월일'].values == lineup[lineup['포지션']=='투수']['생년월일'],1,0)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
# ...

# %%
df.loc[df['name'].isin(['a00','b00','c00'])&(df['math']>=90)]

# %%
df.loc[df['name'].isin(['a00','b00','c00'])&(df['math']>=90)]

# %%
entry.loc[entry['이름'].values == lineup['이름_0'].values ]
# Out:
# <ipython-input-131-0cac56323c9a>:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   entry.loc[entry['이름'].values == lineup['이름_0'].values ]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-0cac56323c9a> in <module>
# ----> 1 entry.loc[entry['이름'].values == lineup['이름_0'].values ]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# ...

# %%
lineup3=lineup[lineup['포지션']=='투수']['이름_0']
lineup3
# Out:
# 9     루친스키
# 19     백정현
# Name: 이름_0, dtype: object

# %%
entry['생년월일']
# Out:
# 0      1974-07-17
# 1      1976-02-08
# 2      1976-09-14
# 3      1981-09-23
# 4      1981-04-09
#           ...
# 362    1993-09-30
# 363    1989-05-18
# 364    1994-02-20
# 365    1985-08-26
# 366    1988-10-02
# Name: 생년월일, Length: 367, dtype: object

# %%
entry['생년월일'][0]
# Out:
# '1974-07-17'

# %%
entry
# Out:
#       등번호   이름  투타유형        생년월일           체격   구분 team  선발유무
# 0    70.0  이동욱  우투우타  1974-07-17  179cm, 81kg   감독   NC     0
# 1    27.0  이호준  우투우타  1976-02-08  187cm, 95kg   코치   NC     0
# 2    74.0  한규식  우투우타  1976-09-14  176cm, 78kg   코치   NC     0
# 3    75.0  진종길  우투좌타  1981-09-23  178cm, 80kg   코치   NC     0
# 4    77.0  용덕한  우투우타  1981-04-09  176cm, 82kg   코치   NC     0
# ..    ...  ...   ...         ...          ...  ...  ...   ...
# 362   NaN  장진혁  우투좌타  1993-09-30  184cm, 83kg  외야수   한화     0
# 363   NaN   호잉  우투좌타  1989-05-18  190cm, 92kg  외야수   한화     0
# 364  10.0  장운호  우투우타  1994-02-20  183cm, 85kg  외야수   한화     0
# 365  19.0  이용규  좌투좌타  1985-08-26  175cm, 70kg  외야수   한화     0
# 366  33.0  정진호  우투좌타  1988-10-02  185cm, 78kg  외야수   한화     0
#
# [367 rows x 8 columns]

# %%
entry['생년월일']
# Out:
# 0      1974-07-17
# 1      1976-02-08
# 2      1976-09-14
# 3      1981-09-23
# 4      1981-04-09
#           ...
# 362    1993-09-30
# 363    1989-05-18
# 364    1994-02-20
# 365    1985-08-26
# 366    1988-10-02
# Name: 생년월일, Length: 367, dtype: object

# %%
lineup['이름'][:][0][4:]
# Out:
# '1993-02-06'

# %%
lineup['이름'][:][1]
# Out:
# '알테어_1991-01-14'

# %%
lineup['이름'][:][1][4:]
# Out:
# '1991-01-14'

# %%
    lineup(lineup['이름'][:][i][4:]==entry['생년월일'] & subset_df['team']==lineup['team'])
    print(lineup(lineup['이름'][:][i][4:]==entry['생년월일'] & subset_df['team']==lineup['team']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     264         #  (xint or xbool) and (yint or bool)
# --> 265         result = op(x, y)
#     266     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'str' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-034c21c8d17b> in <module>
#       1 for i in range(0,10):
# ----> 2     lineup(lineup['이름'][:][i][4:]==entry['생년월일'] & subset_df['team']==lineup['team'])
#       3     print(lineup(lineup['이름'][:][i][4:]==entry['생년월일'] & subset_df['team']==lineup['team']))
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
# ...

# %%
lineup_nc = lineup[lineup['team']=='NC']
lineup_nc
# Out:
#     타순               이름   포지션    투타 team
# 0  1.0   박민우_1993-02-06   2루수  우투좌타   NC
# 1  2.0   알테어_1991-01-14   중견수  우투우타   NC
# 2  3.0   나성범_1989-10-03  지명타자  좌투좌타   NC
# 3  4.0   양의지_1987-06-05    포수  우투우타   NC
# 4  5.0   박석민_1985-06-22   3루수  우투우타   NC
# 5  6.0   모창민_1985-05-08   1루수  우투우타   NC
# 6  7.0   노진혁_1989-07-15   유격수  우투좌타   NC
# 7  8.0   김성욱_1993-05-01   우익수  우투우타   NC
# 8  9.0   이명기_1987-12-26   좌익수  좌투좌타   NC
# 9  NaN  루친스키_1988-12-30    투수  우투우타   NC

# %%
for i, name in enumerate(lineup_nc['이름']):
    lineup_nc['name'][i] = name.split('_')[0]
# Out:
# C:\Users\miran\AppData\Local\Temp\ipykernel_5136\3000670592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lineup_nc['name'][i] = name.split('_')[0]

# %%
#엔트리에서 감독, 코치 제거
player_nc = entry[(entry['team']=='NC') & (entry['구분']!='감독') & (entry['구분']!='코치')]

# %%
lineup_nc[lineup_nc['포지션']=='투수']
# Out:
#    타순               이름 포지션    투타 team  name
# 9 NaN  루친스키_1988-12-30  투수  우투우타   NC  루친스키

# %%
player_nc.drop('선발투수', axis=1, inplace=True)
# Out:
# C:\Users\miran\AppData\Local\Temp\ipykernel_5136\2456009967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_nc.drop('선발투수', axis=1, inplace=True)

# %%
player_nc['선발투수'] = np.where()
# Out:
#      등번호    이름  투타유형        생년월일            체격   구분 team
# 9   12.0   라이트  우투우타  1990-01-03   198cm, 97kg   투수   NC
# 10  24.0   김건태  우투우타  1991-10-02   185cm, 85kg   투수   NC
# 11  30.0   박진우  우언우타  1990-02-12   180cm, 83kg   투수   NC
# 12  38.0   임정호  좌투좌타  1990-04-16   188cm, 90kg   투수   NC
# 13  40.0  루친스키  우투우타  1988-12-30   188cm, 91kg   투수   NC
# 14  45.0   임창민  우투우타  1985-08-25   183cm, 85kg   투수   NC
# 15  46.0   원종현  우언우타  1987-07-31   182cm, 83kg   투수   NC
# 16  59.0   구창모  좌투좌타  1997-02-17   183cm, 85kg   투수   NC
# 17  61.0   배재환  우투우타  1995-02-24   186cm, 95kg   투수   NC
# 18  68.0   강윤구  좌투좌타  1990-07-10   183cm, 89kg   투수   NC
# 19  25.0   양의지  우투우타  1987-06-05   179cm, 85kg   포수   NC
# 20  42.0   김태군  우투우타  1989-12-30   182cm, 92kg   포수   NC
# 21   2.0   박민우  우투좌타  1993-02-06   185cm, 80kg  내야수   NC
# 22   5.0   김찬형  우투우타  1997-12-29   182cm, 80kg  내야수   NC
# 23   7.0   이상호  우투우타  1989-02-05   180cm, 82kg  내야수   NC
# ...
